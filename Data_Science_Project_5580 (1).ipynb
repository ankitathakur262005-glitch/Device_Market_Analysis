# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = '/5580_Ankita_Thakur.xlsx'
data = pd.read_excel(file_path)

# %%
data.head()
# Out:
#    Sr. No.  Device Model Device Type    Brand Operating System  Screen Size  \
# 0        1      Model X1  Smartphone  Samsung          Android          6.5
# 1        2      Model Z2  Smartphone    Apple              iOS          6.1
# 2        3      Model A7      Tablet   Lenovo          Android         10.1
# 3        4      Model Q5  Smartphone   Xiaomi          Android          6.3
# 4        5  Model Pro 12      Laptop       HP       Windows 11         15.6
#
#   Stoarage  Battery Capacity  Price        Use Case  Rating  Weight
# 0      128              4000  66417  Gaming, Social     4.5     180
# 1       64              3000  83217     Photography     4.7     170
# 2       64              6000  20750       Education     4.2     350
# 3      256              5000  53917  Gaming, Travel     4.3     210
# 4      512              7000  99600    Work, Gaming     4.6    1500

# %%
#1. How does the price of devices vary by device type (Smartphone, Tablet, Laptop)?
plt.figure(figsize=(10, 6))
sns.boxplot(x='Device Type', y='Price', data=data)
plt.title('Price Distribution by Device Type')
plt.xlabel('Device Type')
plt.ylabel('Price')
plt.show()

# %%
#2. What is the average rating of devices by their operating system (Android, iOS, Windows, macOS)?
avg_rating = data.groupby('Operating System')['Rating'].mean().reset_index()
plt.figure(figsize=(8, 5))
sns.barplot(x='Operating System', y='Rating', data=avg_rating)
plt.title('Average Rating by Operating System')
plt.xlabel('Operating System')
plt.ylabel('Average Rating')
plt.show()

# %%
#3. How does storage capacity (e.g., 64GB, 128GB, 512GB) correlate with the price of devices?
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='Storage', y='Price')
plt.title('Storage vs Price')
plt.xlabel('Storage (GB)')
plt.ylabel('Price')
plt.show()

# %%
#4. What is the distribution of battery capacities across different device types?
plt.figure(figsize=(10, 6))
sns.boxplot(x='Device Type', y='Battery Capacity', data=data)
plt.title('Battery Capacity Distribution by Device Type')
plt.xlabel('Device Type')
plt.ylabel('Battery Capacity (mAh)')
plt.show()

# %%
#5. What is the average screen size of devices based on their use case (e.g., Gaming, Social, Education, Work)?
plt.figure(figsize=(8, 5))
sns.barplot(x='Use Case', y='Screen Size', data=avg_screen_size)

# Rotate the x-axis labels to avoid overlap
plt.xticks(rotation=45, ha='right')

plt.title('Average Screen Size by Use Case')
plt.xlabel('Use Case')
plt.ylabel('Average Screen Size (inches)')
plt.show()

# %%
#6. How do customer ratings vary based on device weight?
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Weight', y='Rating', data=data)
plt.title('Device Weight vs Customer Ratings')
plt.xlabel('Weight (grams)')
plt.ylabel('Rating')
plt.show()

# %%
#7. What is the price distribution for devices that fall under different use cases (e.g., Gaming, Social, Education)?
plt.figure(figsize=(10, 6))
sns.boxplot(x='Use Case', y='Price', data=data)
plt.title('Price Distribution by Use Case')
plt.xlabel('Use Case')
plt.ylabel('Price')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
#8.How does the weight of smartphones compare to tablets and laptops?
avg_weight = data.groupby('Device Type')['Weight'].mean().reset_index()
plt.figure(figsize=(10, 6))
sns.barplot(x='Device Type', y='Weight', data=avg_weight, palette='coolwarm')
plt.title('Average Weight by Device Type')
plt.xlabel('Device Type')
plt.ylabel('Average Weight (grams)')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-95-28de9d61e50e>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Device Type', y='Weight', data=avg_weight, palette='coolwarm')

# %%
#9. What is the price distribution for devices from different brands (Samsung, Apple, Lenovo, etc.)?
plt.figure(figsize=(12, 6))
sns.boxplot(x='Brand', y='Price', data=data)
plt.xticks(rotation=45)
plt.title('Price Distribution by Brand')
plt.xlabel('Brand')
plt.ylabel('Price')
plt.show()

# %%
#10. How do ratings compare across devices with different battery capacities (e.g., below 4000mAh, 4000mAh to 6000mAh, above 6000mAh)?
data['Battery Category'] = pd.cut(data['Battery Capacity'],
                                  bins=[0, 4000, 6000, data['Battery Capacity'].max()],
                                  labels=['Below 4000mAh', '4000mAh to 6000mAh', 'Above 6000mAh'])

plt.figure(figsize=(10, 6))
sns.boxplot(x='Battery Category', y='Rating', data=data)
plt.title('Ratings by Battery Capacity')
plt.xlabel('Battery Capacity Category')
plt.ylabel('Rating')
plt.show()
